# %% [markdown]
# ### DL condition

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys, os


current_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(current_dir, '..', '../..'))  # goes two levels up to MOSAIC
print("Project root:",project_root)
sys.path.append(project_root)

from configs.dreamachine2 import config

sanitized_model_name = config.transformer_model.replace('/', '_') #name of the transformer model with '/' replaced by '_'
file_path = f'OPTUNA_results_DL_sentences_{sanitized_model_name}.csv'
df = pd.read_csv(file_path)


df['best_embedding_coherence'] = df['embedding_coherence'].cummax()

plt.figure(figsize=(12, 7))
plt.plot(df['trial_number'], df['best_embedding_coherence'], marker='.', linestyle='-', color='b', alpha=0.7)

plt.title('Optuna Optimisation History (DL)', fontsize=16)
plt.xlabel('Trial Number', fontsize=12)
plt.ylabel('Best Embedding Coherence Found So Far', fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

# plt.savefig('optimization_history_DL.png')

plt.show()
# Out:
# Project root: /Users/rb666/Projects/MOSAIC

# %%
file_path = f'OPTUNA_results_DL_sentences_multiobj_{sanitized_model_name}.csv'
df = pd.read_csv(file_path)

df['objective_embed_coherence'] = df['objective_embed_coherence'].cummax()
df['objective_cv'] = df['objective_cv'].cummax()

plt.figure(figsize=(12, 7))
plt.plot(df['trial_number'], df['objective_embed_coherence'], marker='.', linestyle='-', color='b', alpha=0.7, label='Objective Embed Coherence')
plt.plot(df['trial_number'], df['objective_cv'], marker='.', linestyle='-', color='g', alpha=0.7, label='Objective CV')

plt.title('Optuna Optimisation History (DL)', fontsize=16)
plt.xlabel('Trial Number', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### HS condition

# %%
file_path = f'OPTUNA_results_HS_sentences_{sanitized_model_name}.csv'
df = pd.read_csv(file_path)


df['best_embedding_coherence'] = df['embedding_coherence'].cummax()

plt.figure(figsize=(12, 7))
plt.plot(df['trial_number'], df['best_embedding_coherence'], marker='.', linestyle='-', color='b', alpha=0.7)

plt.title('Optuna Optimisation History (HS)', fontsize=16)
plt.xlabel('Trial Number', fontsize=12)
plt.ylabel('Best Embedding Coherence Found So Far', fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

# plt.savefig('optimization_history_HS.png')

plt.show()

# %%
file_path = f'OPTUNA_results_HS_sentences_multiobj_{sanitized_model_name}.csv'
df = pd.read_csv(file_path)

df['objective_embed_coherence'] = df['objective_embed_coherence'].cummax()
df['objective_cv'] = df['objective_cv'].cummax()

plt.figure(figsize=(12, 7))
plt.plot(df['trial_number'], df['objective_embed_coherence'], marker='.', linestyle='-', color='b', alpha=0.7, label='Objective Embed Coherence')
plt.plot(df['trial_number'], df['objective_cv'], marker='.', linestyle='-', color='g', alpha=0.7, label='Objective CV')

plt.title('Optuna Optimisation History (HS)', fontsize=16)
plt.xlabel('Trial Number', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

plt.show()
